# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Math

# %matplotlib inline

# %%
train = pd.read_csv('data/titanic_train_model.csv', index_col="PassengerId")
X = train.drop('Survived', axis=1)
y = train.Survived

# %%
train.sort_values(by='Survived').head()
# Out:
#                Pclass       Sex       Age     SibSp     Parch      Fare  \
# PassengerId
# 1            0.827377 -0.737695 -0.592481  0.432793 -0.473674 -0.502445
# 520          0.827377 -0.737695  0.177063 -0.474545 -0.473674 -0.489442
# 522          0.827377 -0.737695 -0.592481 -0.474545 -0.473674 -0.489442
# 523          0.827377 -0.737695  0.000000 -0.474545 -0.473674 -0.502949
# 525          0.827377 -0.737695  0.000000 -0.474545 -0.473674 -0.502864
#
#              Embarked  PersonType    Title  Survived
# PassengerId
# 1           -0.571933   -0.742596 -0.71219         0
# 520         -0.571933   -0.742596 -0.71219         0
# 522         -0.571933   -0.742596 -0.71219         0
# 523          1.000883   -0.742596 -0.71219         0
# 525          1.000883   -0.742596 -0.71219         0

# %%
y.head()
# Out:
# PassengerId
# 1    0
# 2    1
# 3    1
# 4    1
# 5    0
# Name: Survived, dtype: int64

# %%
X[X['Age'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pclass, Sex, Age, SibSp, Parch, Fare, Embarked, PersonType, Title]
# Index: []

# %% [markdown]
# ## 1. Linear Models

# %% [markdown]
# ![validation](images/linear_regression.png)

# %% [markdown]
# $$ \frac{1}{2m} \sum_i (h(x_i) - y_i)^2 \text{ mit } h(x) = m*x + t$$
# $$  $$

# %%
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression()

# %% [markdown]
# ### Model fitting

# %%
model_lr.fit(X,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
model_lr.score(X,y)
# Out:
# 0.81818181818181823

# %% [markdown]
# There are lots of estimators in sklearn. They all share a common interface. Thus it's easy to use estimators even when you don't fully understand how they work. Though make sure to read at least the doc string documentation about an estimator before using it.

# %% [markdown]
# ## Estimator API
#
# ### 1. estimator.fit(X_train, y_train)
# - Trains the model using training data X und training labels y
#
# ### 2. estimator.predict(X_test)
# - Uses the prior trained model to predict labels (callsification), values (regression) for test data
#
# ### 3. estimator.score(X_val, y_val)
# - Uses estimator.predict(X_val) to predict the labels/values, then uses the given labels y_val to score the result

# %% [markdown]
# ## 2. How do wen know if our model is actually useful? => Validation
# Every estimator has its advantages and drawbacks. Its generalization error can be decomposed in terms of bias, variance and noise. The bias of an estimator is its average error for different data sets. The variance of an estimator indicates how sensitive it is to varying data sets. Noise is a property of the data. The estimator has no impact on the noise in the data thus we can only try to lower the variance and the bias of an estimator.

# %% [markdown]
# error = bias + variance + (noise)

# %% [markdown]
# Our goal is find an estimator which is able to generalize well to new/unseen data sets.

# %% [markdown]
# ### How do we know if our estimator has high bias/variance?
# We need some new/unknown data for which we know the correct labels in order to test our model. We can't use our test data as we don't know the correct labels. That's why there is now other possibility but to take it from our valuable training data. This data set is called validation data set.
#
# **Overfitting:** Small training error + Large validation error => Reduce model complexity + Regularization
# **Underfitting:** Large training error + Large validation error => Increase model complexity

# %%
train.sort_values(by='Survived', inplace=True)
X = train.drop('Survived', axis=1)
y = train.Survived

# %% [markdown]
# ### Split data: data => train data, validation data

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=3, stratify=None, shuffle=False)

# %%
X_val[y_val == 0]
# Out:
# Empty DataFrame
# Columns: [Pclass, Sex, Age, SibSp, Parch, Fare, Embarked, PersonType, Title]
# Index: []

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=3, stratify=y, shuffle=True)

# %%
X_val[y_val == 0].head(10)
# Out:
#                Pclass       Sex       Age     SibSp     Parch      Fare  \
# PassengerId
# 168          0.827377  1.355574  1.177469  0.432793  4.491540 -0.086664
# 500          0.827377 -0.737695 -0.438572 -0.474545 -0.473674 -0.491456
# 154          0.827377 -0.737695  0.831175 -0.474545  2.008933 -0.356469
# 264         -1.566107 -0.737695  0.792698 -0.474545 -0.473674 -0.648422
# 374         -1.566107 -0.737695 -0.592481 -0.474545 -0.473674  2.082512
# 355          0.827377 -0.737695  0.000000 -0.474545 -0.473674 -0.502949
# 424          0.827377  1.355574 -0.130754  0.432793  0.767630 -0.358482
# 516         -1.566107 -0.737695  1.331378 -0.474545 -0.473674  0.036577
# 251          0.827377 -0.737695  0.000000 -0.474545 -0.473674 -0.502445
# 120          0.827377  1.355574 -2.131568  3.154809  2.008933 -0.018709
#
#              Embarked  PersonType     Title
# PassengerId
# 168         -0.571933    0.771484  0.163067
# 500         -0.571933   -0.742596 -0.712190
# 154         -0.571933   -0.742596 -0.712190
# 264         -0.571933   -0.742596 -0.712190
# 374          1.000883   -0.742596 -0.712190
# 355          1.000883   -0.742596 -0.712190
# 424         -0.571933    0.771484  0.163067
# 516         -0.571933   -0.742596 -0.712190
# 251         -0.571933   -0.742596 -0.712190
# 120         -0.571933    2.285565  1.038323

# %%
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
model_lr.score(X_val, y_val)
# Out:
# 0.83582089552238803

# %%
from sklearn import linear_model

# %% [markdown]
# ## Regularization (L1 and L2)

# %%
model_l1 = linear_model.LogisticRegression(penalty='l1', C=0.1) # C = 1/lambda
model_l2 = linear_model.LogisticRegression(penalty='l2', C=0.01) # C = 1/lambda

# %%
model_l1.fit(X_train, y_train)
model_l2.fit(X_train, y_train);

# %%
model_l1.score(X_val, y_val), model_l2.score(X_val, y_val)
# Out:
# (0.82462686567164178, 0.81343283582089554)

# %% [markdown]
# ## First submission

# %%
submission = pd.read_csv("data/titanic_gender_submission.csv", index_col="PassengerId")
test = pd.read_csv("data/titanic_test_model.csv", index_col="PassengerId")

# %%
model_l1.fit(X,y)
# Out:
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
model_l1.score(X,y)
# Out:
# 0.8125701459034792

# %%
prediction = model_l1.predict(test)

# %%
test.head()
# Out:
#                Pclass       Sex       Age     SibSp     Parch      Fare  \
# PassengerId
# 892          0.827377 -0.737695  0.369449 -0.474545 -0.473674 -0.490783
# 893          0.827377  1.355574  1.331378  0.432793 -0.473674 -0.507479
# 894         -0.369365 -0.737695  2.485693 -0.474545 -0.473674 -0.453367
# 895          0.827377 -0.737695 -0.207709 -0.474545 -0.473674 -0.474005
# 896          0.827377  1.355574 -0.592481  0.432793  0.767630 -0.401017
#
#              Embarked  PersonType     Title
# PassengerId
# 892         -0.571933   -0.742596 -0.712190
# 893          1.000883    0.771484  0.163067
# 894         -0.571933   -0.742596 -0.712190
# 895          1.000883   -0.742596 -0.712190
# 896          1.000883    0.771484  0.163067

# %%
prediction = pd.DataFrame(data=prediction, index=test.index, columns=['Survived'])

# %%
## TEST
#prediction.Survived = 0 # result: 0.62679 (public leaderboard)

# %%
prediction.head()
# Out:
#              Survived
# PassengerId
# 892                 0
# 893                 1
# 894                 0
# 895                 0
# 896                 1

# %%
prediction.to_csv("data/submission_01.csv", index=True, index_label="PassengerId")

# %% [markdown]
# ## Error analysis
# The concept is quite simple. You make predictions for the validation set. Then you compare your results with the correct labels. It takes a lot of time but can give you some additional insights.

# %%
X_val_prediction = model_l1.predict(X_val)

# %%
X_val_prediction = pd.DataFrame(data=X_val_prediction, index=X_val.index, columns=['Survived'])

# %%
X_val_prediction.head()
# Out:
#              Survived
# PassengerId
# 577                 1
# 168                 0
# 500                 0
# 154                 0
# 193                 1

# %%
X_val_prediction['Survived'] == y_val[1]
# Out:
# PassengerId
# 577    False
# 168     True
# 500     True
# 154     True
# 193    False
# 751    False
# 264     True
# 208     True
# 374    False
# 355     True
# 508     True
# 424    False
# 413    False
# 516     True
# 59     False
# 251     True
# 120    False
# 623     True
# 305     True
# 847     True
# 316    False
# 40     False
# 503    False
# 405    False
# 112    False
# 586    False
# 177     True
# 60      True
# 320    False
# 872    False
#        ...
# 434     True
# 812     True
# 860     True
# 497    False
# 380     True
# 94      True
# 24      True
# 557    False
# 340     True
# 286     True
# 284     True
# 221     True
# 825     True
# 9      False
# 41     False
# 389     True
# 638     True
# 170     True
# 319    False
# 393     True
# 194    False
# 400    False
# 426     True
# 488     True
# 859    False
# 813     True
# 655    False
# 109     True
# 127     True
# 45     False
# Name: Survived, Length: 268, dtype: bool

# %%
X_val[X_val_prediction['Survived'] != y_val[1]]
# Out:
#                Pclass       Sex       Age     SibSp     Parch      Fare  \
# PassengerId
# 577         -0.369365  1.355574  0.330972 -0.474545 -0.473674 -0.386671
# 193          0.827377  1.355574 -0.823344  0.432793 -0.473674 -0.490280
# 751         -0.369365  1.355574 -1.977659  0.432793  0.767630 -0.185324
# 374         -1.566107 -0.737695 -0.592481 -0.474545 -0.473674  2.082512
# 424          0.827377  1.355574 -0.130754  0.432793  0.767630 -0.358482
# 413         -1.566107  1.355574  0.254017  0.432793 -0.473674  1.163700
# 59          -0.369365  1.355574 -1.900705  0.432793  2.008933 -0.089684
# 120          0.827377  1.355574 -2.131568  3.154809  2.008933 -0.018709
# 316          0.827377  1.355574 -0.284663 -0.474545 -0.473674 -0.490280
# 40           0.827377  1.355574 -1.208115  0.432793 -0.473674 -0.422074
# 503          0.827377  1.355574  0.000000 -0.474545 -0.473674 -0.494810
# 405          0.827377  1.355574 -0.746389 -0.474545 -0.473674 -0.474005
# 112          0.827377  1.355574 -1.169638  0.432793 -0.473674 -0.357391
# 586         -1.566107  1.355574 -0.900298 -0.474545  2.008933  0.955306
# 320         -1.566107  1.355574  0.792698  0.432793  0.767630  2.059694
# 872         -1.566107  1.355574  1.331378  0.432793  0.767630  0.409741
# 157          0.827377  1.355574 -1.054207 -0.474545 -0.473674 -0.492714
# 480          0.827377  1.355574 -2.131568 -0.474545  0.767630 -0.401017
# 148          0.827377  1.355574 -1.592887  1.340132  2.008933  0.043708
# 294          0.827377  1.355574 -0.438572 -0.474545 -0.473674 -0.470230
# 645          0.827377  1.355574 -2.227761  1.340132  0.767630 -0.260662
# 252          0.827377  1.355574 -0.053800  0.432793  0.767630 -0.437762
# 212         -0.369365  1.355574  0.407926 -0.474545 -0.473674 -0.225593
# 324         -0.369365  1.355574 -0.592481  0.432793  0.767630 -0.064516
# 418         -0.369365  1.355574 -0.900298 -0.474545  2.008933 -0.386671
# 728          0.827377  1.355574  0.000000 -0.474545 -0.473674 -0.492630
# 323         -0.369365  1.355574  0.023154 -0.474545 -0.473674 -0.399758
# 843         -1.566107  1.355574  0.023154 -0.474545 -0.473674 -0.024246
# 732          0.827377 -0.737695 -1.438978 -0.474545 -0.473674 -0.270141
# 269         -1.566107  1.355574  2.177876 -0.474545  0.767630  2.441498
# ...               ...       ...       ...       ...       ...       ...
# 420          0.827377  1.355574 -1.515933 -0.474545  2.008933 -0.162169
# 301          0.827377  1.355574  0.000000 -0.474545 -0.473674 -0.492378
# 12          -1.566107  1.355574  2.177876 -0.474545 -0.473674 -0.113846
# 814          0.827377  1.355574 -1.823750  3.154809  2.008933 -0.018709
# 308         -1.566107  1.355574 -0.977252  0.432793 -0.473674  1.544246
# 755         -0.369365  1.355574  1.408333  0.432793  2.008933  0.660333
# 857         -1.566107  1.355574  1.177469  0.432793  0.767630  2.671118
# 541         -1.566107  1.355574  0.484880 -0.474545  2.008933  0.781141
# 830         -1.566107  1.355574  2.485693 -0.474545 -0.473674  0.962353
# 594          0.827377  1.355574  0.000000 -0.474545  2.008933 -0.492378
# 550         -0.369365 -0.737695 -1.669842  0.432793  0.767630  0.091528
# 619         -0.369365  1.355574 -1.977659  1.340132  0.767630  0.136831
# 582         -1.566107  1.355574  0.715743  0.432793  0.767630  1.584179
# 50           0.827377  1.355574 -0.900298  0.432793 -0.473674 -0.290024
# 162         -0.369365  1.355574  0.792698 -0.474545 -0.473674 -0.331300
# 276         -1.566107  1.355574  2.562648  0.432793 -0.473674  0.921244
# 33           0.827377  1.355574  0.000000 -0.474545 -0.473674 -0.492378
# 384         -1.566107  1.355574  0.407926  0.432793 -0.473674  0.398582
# 390         -0.369365  1.355574 -0.977252 -0.474545 -0.473674 -0.406805
# 658          0.827377  1.355574  0.177063  0.432793  0.767630 -0.336334
# 497         -1.566107  1.355574  1.870059  0.432793 -0.473674  0.927454
# 557         -1.566107  1.355574  1.408333  0.432793 -0.473674  0.148912
# 9            0.827377  1.355574 -0.207709 -0.474545  2.008933 -0.424256
# 41           0.827377  1.355574  0.792698  0.432793 -0.473674 -0.457645
# 319         -1.566107  1.355574  0.100109 -0.474545  2.008933  2.671118
# 194         -0.369365 -0.737695 -2.054613  0.432793  0.767630 -0.124920
# 400         -0.369365  1.355574 -0.130754 -0.474545 -0.473674 -0.393718
# 859          0.827377  1.355574 -0.438572 -0.474545  3.250237 -0.260662
# 655          0.827377  1.355574 -0.900298 -0.474545 -0.473674 -0.512513
# 45           0.827377  1.355574 -0.823344 -0.474545 -0.473674 -0.489776
#
#              Embarked  PersonType     Title
# PassengerId
# 577         -0.571933    0.771484  1.038323
# 193         -0.571933    0.771484  1.038323
# 751         -0.571933    2.285565  1.038323
# 374          1.000883   -0.742596 -0.712190
# 424         -0.571933    0.771484  0.163067
# 413          2.573699    0.771484  1.038323
# 59          -0.571933    2.285565  1.038323
# 120         -0.571933    2.285565  1.038323
# 316         -0.571933    0.771484  1.038323
# 40           1.000883    2.285565  1.038323
# 503          2.573699    0.771484  1.038323
# 405         -0.571933    0.771484  1.038323
# 112          1.000883    2.285565  1.038323
# 586         -0.571933    0.771484  1.038323
# 320          1.000883    0.771484  0.163067
# 872         -0.571933    0.771484  0.163067
# 157          2.573699    0.771484  1.038323
# 480         -0.571933    2.285565  1.038323
# 148         -0.571933    2.285565  1.038323
# 294         -0.571933    0.771484  1.038323
# 645          1.000883    2.285565  1.038323
# 252         -0.571933    0.771484  0.163067
# 212         -0.571933    0.771484  1.038323
# 324         -0.571933    0.771484  0.163067
# 418         -0.571933    0.771484  1.038323
# 728          2.573699    0.771484  1.038323
# 323          2.573699    0.771484  1.038323
# 843          1.000883    0.771484  1.038323
# 732          1.000883    2.285565 -0.712190
# 269         -0.571933    0.771484  0.163067
# ...               ...         ...       ...
# 420         -0.571933    2.285565  1.038323
# 301          2.573699    0.771484  1.038323
# 12          -0.571933    0.771484  1.038323
# 814         -0.571933    2.285565  1.038323
# 308          1.000883    0.771484  0.163067
# 755         -0.571933    0.771484  0.163067
# 857         -0.571933    0.771484  0.163067
# 541         -0.571933    0.771484  1.038323
# 830          1.000883    0.771484  0.163067
# 594          2.573699    0.771484  1.038323
# 550         -0.571933    2.285565  1.913580
# 619         -0.571933    2.285565  1.038323
# 582          1.000883    0.771484  0.163067
# 50          -0.571933    0.771484  0.163067
# 162         -0.571933    0.771484  0.163067
# 276         -0.571933    0.771484  1.038323
# 33           2.573699    0.771484  1.038323
# 384         -0.571933    0.771484  0.163067
# 390          1.000883    0.771484  1.038323
# 658          2.573699    0.771484  0.163067
# 497          1.000883    0.771484  1.038323
# 557          1.000883    0.771484  2.788837
# 9           -0.571933    0.771484  0.163067
# 41          -0.571933    0.771484  0.163067
# 319         -0.571933    0.771484  1.038323
# 194         -0.571933    2.285565  1.913580
# 400         -0.571933    0.771484  0.163067
# 859          1.000883    0.771484  0.163067
# 655          2.573699    0.771484  1.038323
# 45           2.573699    0.771484  1.038323
#
# [109 rows x 9 columns]

# %% [markdown]
# ## 2. Decison Trees

# %%
from sklearn.tree import DecisionTreeClassifier
model_dt = DecisionTreeClassifier(criterion='gini')

# %%
model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
model_dt.score(X_train, y_train) , model_dt.score(X_val, y_val)
# Out:
# (0.9887640449438202, 0.77985074626865669)

# %% [markdown]
# Our model is overfitting.
# ### Excercise: Create a new model which doesn't overfit

# %%
## Your Code here

# %% [markdown]
# ## 3. K Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier
model_k = KNeighborsClassifier(n_neighbors=4)

# %%
model_k.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#            weights='uniform')

# %%
model_k.score(X_train, y_train), model_k.score(X_val, y_val)
# Out:
# (0.85874799357945431, 0.81716417910447758)

# %%
train_pred = model_k.predict(X_train)

# %%
X_train[train_pred != y_train]
# Out:
#                Pclass       Sex       Age     SibSp     Parch      Fare  \
# PassengerId
# 588         -1.566107 -0.737695  2.331785  0.432793  0.767630  0.946246
# 608         -1.566107 -0.737695 -0.207709 -0.474545 -0.473674 -0.034314
# 646         -1.566107 -0.737695  1.408333  0.432793 -0.473674  0.896497
# 800          0.827377  1.355574  0.023154  0.432793  0.767630 -0.162169
# 708         -1.566107 -0.737695  0.946606 -0.474545 -0.473674 -0.119131
# 142          0.827377  1.355574 -0.592481 -0.474545 -0.473674 -0.492378
# 713         -1.566107 -0.737695  1.408333  0.432793 -0.473674  0.398582
# 534          0.827377  1.355574  0.000000 -0.474545  2.008933 -0.198244
# 302          0.827377 -0.737695  0.000000  1.340132 -0.473674 -0.180290
# 853          0.827377  1.355574 -1.592887  0.432793  0.767630 -0.341452
# 797         -1.566107  1.355574  1.485287 -0.474545 -0.473674 -0.126345
# 430          0.827377 -0.737695  0.177063 -0.474545 -0.473674 -0.486337
# 470          0.827377  1.355574 -2.227761  1.340132  0.767630 -0.260662
# 456          0.827377 -0.737695 -0.053800 -0.474545 -0.473674 -0.489442
# 858         -1.566107 -0.737695  1.639196 -0.474545 -0.473674 -0.113846
# 511          0.827377 -0.737695 -0.053800 -0.474545 -0.473674 -0.492378
# 681          0.827377  1.355574  0.000000 -0.474545 -0.473674 -0.484576
# 502          0.827377  1.355574 -0.669435 -0.474545 -0.473674 -0.492378
# 415          0.827377 -0.737695  1.100515 -0.474545 -0.473674 -0.488854
# 86           0.827377  1.355574  0.254017  2.247470 -0.473674 -0.329287
# 560          0.827377  1.355574  0.484880  0.432793 -0.473674 -0.298078
# 22          -0.369365 -0.737695  0.330972 -0.474545 -0.473674 -0.386671
# 143          0.827377  1.355574 -0.438572  0.432793 -0.473674 -0.329287
# 745          0.827377 -0.737695  0.100109 -0.474545 -0.473674 -0.488854
# 580          0.827377 -0.737695  0.177063 -0.474545 -0.473674 -0.488854
# 674         -0.369365 -0.737695  0.100109 -0.474545 -0.473674 -0.386671
# 227         -0.369365 -0.737695 -0.823344 -0.474545 -0.473674 -0.437007
# 544         -0.369365 -0.737695  0.177063  0.432793 -0.473674 -0.124920
# 805          0.827377 -0.737695 -0.207709 -0.474545 -0.473674 -0.507982
# 600         -1.566107 -0.737695  1.485287  0.432793 -0.473674  0.497830
# ...               ...       ...       ...       ...       ...       ...
# 450         -1.566107 -0.737695  1.716150 -0.474545 -0.473674 -0.034314
# 554          0.827377 -0.737695 -0.592481 -0.474545 -0.473674 -0.502949
# 725         -1.566107 -0.737695 -0.207709  0.432793 -0.473674  0.420730
# 217          0.827377  1.355574 -0.207709 -0.474545 -0.473674 -0.488854
# 225         -1.566107 -0.737695  0.638789  0.432793 -0.473674  1.163700
# 829          0.827377 -0.737695  0.000000 -0.474545 -0.473674 -0.492378
# 485         -1.566107 -0.737695 -0.361618  0.432793 -0.473674  1.185430
# 108          0.827377 -0.737695  0.000000 -0.474545 -0.473674 -0.491874
# 445          0.827377 -0.737695  0.000000 -0.474545 -0.473674 -0.485079
# 200         -0.369365  1.355574 -0.438572 -0.474545 -0.473674 -0.386671
# 827          0.827377 -0.737695  0.000000 -0.474545 -0.473674  0.489104
# 741         -1.566107 -0.737695  0.000000 -0.474545 -0.473674 -0.044381
# 665          0.827377 -0.737695 -0.746389  0.432793 -0.473674 -0.488854
# 234          0.827377  1.355574 -1.900705  3.154809  2.008933 -0.016444
# 129          0.827377  1.355574  0.000000  0.432793  0.767630 -0.198244
# 272          0.827377 -0.737695 -0.361618 -0.474545 -0.473674 -0.648422
# 3            0.827377  1.355574 -0.284663 -0.474545 -0.473674 -0.488854
# 691         -1.566107 -0.737695  0.100109  0.432793 -0.473674  0.499256
# 855         -0.369365  1.355574  1.100515  0.432793 -0.473674 -0.124920
# 484          0.827377  1.355574  2.562648 -0.474545 -0.473674 -0.455380
# 249         -1.566107 -0.737695  0.561835  0.432793  0.767630  0.409741
# 768          0.827377  1.355574  0.061631 -0.474545 -0.473674 -0.492378
# 551         -1.566107 -0.737695 -0.977252 -0.474545  2.008933  1.584179
# 18          -0.369365 -0.737695  0.000000 -0.474545 -0.473674 -0.386671
# 682         -1.566107 -0.737695 -0.207709 -0.474545 -0.473674  0.896497
# 377          0.827377  1.355574 -0.592481 -0.474545 -0.473674 -0.502445
# 631         -1.566107 -0.737695  3.870872 -0.474545 -0.473674 -0.044381
# 289         -0.369365 -0.737695  0.946606 -0.474545 -0.473674 -0.386671
# 798          0.827377  1.355574  0.100109 -0.474545 -0.473674 -0.473586
# 692          0.827377  1.355574 -1.977659 -0.474545  0.767630 -0.378281
#
#              Embarked  PersonType     Title
# PassengerId
# 588          1.000883   -0.742596 -0.712190
# 608         -0.571933   -0.742596 -0.712190
# 646          1.000883   -0.742596 -0.712190
# 800         -0.571933    0.771484  0.163067
# 708         -0.571933   -0.742596 -0.712190
# 142         -0.571933    0.771484  1.038323
# 713         -0.571933   -0.742596 -0.712190
# 534          1.000883    0.771484  0.163067
# 302          2.573699   -0.742596 -0.712190
# 853          1.000883    2.285565  1.038323
# 797         -0.571933    0.771484  3.664093
# 430         -0.571933   -0.742596 -0.712190
# 470          1.000883    2.285565  1.038323
# 456          1.000883   -0.742596 -0.712190
# 858         -0.571933   -0.742596 -0.712190
# 511          2.573699   -0.742596 -0.712190
# 681          2.573699    0.771484  1.038323
# 502          2.573699    0.771484  1.038323
# 415         -0.571933   -0.742596 -0.712190
# 86          -0.571933    0.771484  0.163067
# 560         -0.571933    0.771484  0.163067
# 22          -0.571933   -0.742596 -0.712190
# 143         -0.571933    0.771484  0.163067
# 745         -0.571933   -0.742596 -0.712190
# 580         -0.571933   -0.742596 -0.712190
# 674         -0.571933   -0.742596 -0.712190
# 227         -0.571933   -0.742596 -0.712190
# 544         -0.571933   -0.742596 -0.712190
# 805         -0.571933   -0.742596 -0.712190
# 600          1.000883   -0.742596  2.788837
# ...               ...         ...       ...
# 450         -0.571933   -0.742596  3.664093
# 554          1.000883   -0.742596 -0.712190
# 725         -0.571933   -0.742596 -0.712190
# 217         -0.571933    0.771484  1.038323
# 225         -0.571933   -0.742596 -0.712190
# 829          2.573699   -0.742596 -0.712190
# 485          1.000883   -0.742596 -0.712190
# 108         -0.571933   -0.742596 -0.712190
# 445         -0.571933   -0.742596 -0.712190
# 200         -0.571933    0.771484  1.038323
# 827         -0.571933   -0.742596 -0.712190
# 741         -0.571933   -0.742596 -0.712190
# 665         -0.571933   -0.742596 -0.712190
# 234         -0.571933    2.285565  1.038323
# 129          1.000883    0.771484  1.038323
# 272         -0.571933   -0.742596 -0.712190
# 3           -0.571933    0.771484  1.038323
# 691         -0.571933   -0.742596 -0.712190
# 855         -0.571933    0.771484  0.163067
# 484         -0.571933    0.771484  0.163067
# 249         -0.571933   -0.742596 -0.712190
# 768          2.573699    0.771484  1.038323
# 551          1.000883   -0.742596 -0.712190
# 18          -0.571933   -0.742596 -0.712190
# 682          1.000883   -0.742596 -0.712190
# 377         -0.571933    0.771484  1.038323
# 631         -0.571933   -0.742596 -0.712190
# 289         -0.571933   -0.742596 -0.712190
# 798         -0.571933    0.771484  0.163067
# 692          1.000883    2.285565  1.038323
#
# [88 rows x 9 columns]

# %% [markdown]
# ### Excercise: Find the best parameter for k

# %%
## Your Code here

# %% [markdown]
# ## 4. Hyperparameter optimization
# Normal parameters: Parameters which can be learnt by the model
# Hyper paramaters: Parameters which define the structure or learning process of the model

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### KNN

# %%
## KNN
param_grid = [
  {'n_neighbors': [1,2,3,4,5,6,7,8]}]
gs_knn = GridSearchCV(model_k,param_grid=param_grid)

# %%
gs_knn.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=4, p=2,
#            weights='uniform'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'n_neighbors': [1, 2, 3, 4, 5, 6, 7, 8]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
gs_knn.best_params_
# Out:
# {'n_neighbors': 6}

# %%
gs_knn.best_score_
# Out:
# 0.8105939004815409

# %%
model_k = gs_knn.best_estimator_

# %% [markdown]
# ### Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
param_grid = [
    {'max_depth': (range(1,10)),
     'max_features': (range(1,6)),
     'min_samples_leaf': (range(1,10)),}
    ]  

model_dt = DecisionTreeClassifier()

gs_dt = GridSearchCV(model_dt,param_grid)

# %%
gs_dt.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'max_depth': range(1, 10), 'max_features': range(1, 6), 'min_samples_leaf': range(1, 10)}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
gs_dt.best_params_
# Out:
# {'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 1}

# %% [markdown]
# ### Further reading: RandomSearchCV, scikit-optimize

# %% [markdown]
# ## 5. Ensemble methods

# %% [markdown]
# ### Bagging and Random Forest

# %%
from sklearn.ensemble.forest import RandomForestClassifier
model_rf = RandomForestClassifier(n_estimators=15)

# %%
model_rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=15, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
model_rf.score(X_val, y_val)
# Out:
# 0.83582089552238803

# %% [markdown]
# ### General bagging classifier (combine whatever models you want)

# %%
from sklearn.ensemble.bagging import BaggingClassifier
model_bagging = BaggingClassifier()

# %% [markdown]
# ### Boosting and GBDT

# %%
from sklearn.ensemble.gradient_boosting import GradientBoostingClassifier
model_gbdt = GradientBoostingClassifier(learning_rate=0.1)

# %%
model_gbdt.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
model_gbdt.score(X_val, y_val)
# Out:
# 0.83955223880597019

# %%
model_gbdt.fit(X,y)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
prediction = model_gbdt.predict(test)

# %%
prediction = pd.DataFrame(data=prediction, index=test.index, columns=['Survived'])

# %%
prediction.head()
# Out:
#              Survived
# PassengerId
# 892                 0
# 893                 0
# 894                 0
# 895                 0
# 896                 1

# %%
prediction.to_csv("data/submission_02.csv", index=True, index_label="PassengerId")

# %%
gb_grid_params = {'learning_rate': [0.1, 0.05, 0.02, 0.01],
              'max_depth': [4, 6, 8, 10],
              'min_samples_leaf': [20, 50,100,150],
              #'max_features': [1.0, 0.3, 0.1] 
              }

gb_gs = GradientBoostingClassifier(n_estimators = 600)

clf = GridSearchCV(model_gbdt, gb_grid_params, cv=2);

# %%
clf.fit(X,y)

# %%
clf.best_params_

# %%
prediction_new = clf.predict(test)

# %%
prediction_new = pd.DataFrame(data=prediction_new, index=test.index, columns=['Survived'])

# %%
test[prediction_new['Survived'] != prediction['Survived']]

# %%
prediction_new.to_csv("data/submission_03.csv", index=True, index_label="PassengerId")
